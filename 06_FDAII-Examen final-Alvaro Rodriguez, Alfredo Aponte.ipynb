# %% [markdown]
# Fundamentos de analítica 2 (trabajo final)
#
# Alfredo Aponte, Álvaro Rodríguez
#
# Profesor Diego Fernando Agudelo
#
# Universidad ICESI
#
# diegoagudelo30@gmail.com

# %% [markdown]
# ## 0. Contexto
#
# **Parcial final**
#
# **Instrucciones**
# El examen se compone de dos partes:
# - La primera corresponde a una parte de selección múltiple con 19 preguntas que se responderán en el salón de clase en 45 minutos. Esa primera parte tiene una calificación de 1 a 5.
# -La segunda parte corresponde a la parte práctica del examen y tiene también una calificación de 1 a 5.
#
# - La nota de este examen parcial corresponderá al promedio ponderado de las dos notas, donde la parte práctica tiene un peso de 40 % y la parte de selección múltiple de 60 %.
# - Usted tiene hasta el 30 de agosto a las 12:00 pm para enviar los archivos por correo, estos archivos deben tener su nombre.
# - Sólo se calificaran exámenes en formato pdf. Cualquier otro formato no será tenido en cuenta.
# - El examen debe estar acompañado de un notebook (ipynb)  que incluya todo los códigos de python que se emplean para obtener sus resultados.
# - El nombre del archivo debe tener su nombre. No se recibirán archivos en otro formato.
# - Esta parte del examen es para realizar en casa y debe reflejar el trabajo individual.
#
# **El Problema**
#
# En días recientes trabajamos con una compañía de comestibles que estaba interesada en predecir el comportamiento de las ventas (en unidades) de sus dos productos estrella. Fuimos contratados para generar un modelo que permita pronosticar las ventas del siguiente mes de cada uno de esos dos productos. La base de datos disponible en el archivo Examen.csv tiene la información de cada uno de los productos desde enero de 2008.
#
# Su misión es encontrar el mejor modelo para pronosticar cada una de las series. Usted debe entregar un informe escrito de no más de cuatro páginas que presente los resultados al cliente y cuente el proceso para llegar a los pronósticos. Vea las instrucciones para asegurar que entrega los archivos requeridos.

# %% [markdown]
# ## **1. Carga de paquetes**

# %%
import numpy as np
import pandas as pd # Operaciones con dataframes
from matplotlib import pyplot as plt # gráficos
from statsmodels.tsa.seasonal import seasonal_decompose # descomposición de series
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from sklearn.metrics import mean_squared_error
import optuna
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **2. Carga de datos**
#
# Nuestra primera tarea será leer el archivo. Para eso podemos emplear el paquete Pandas. Carguemos los datos en un objeto que denominaremos data.

# %%
data = pd.read_csv("Examen.csv")
data.columns.values[0] = "corte"
data["Fecha"] = pd.date_range(start="2008-01-01", periods=len(data), freq="MS")
data["indice"] = data["corte"] - 1
data.set_index("Fecha",inplace=True)
columnas = data.columns.tolist()
columnas.remove("indice")
columnas.insert(0, "indice")
data = data[columnas]
data.head(3)
# Out:
#             indice  corte    producto1    producto2
# Fecha
# 2008-01-01       0      1  4000.000000  3000.000000
# 2008-02-01       1      2  3997.400893  3010.686220
# 2008-03-01       2      3  3978.605317  3022.018584

# %% [markdown]
# Graficamos la series para ver su comportamiento

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
ax1.set_title("Serie producto 1")
ax1.set_xlabel("Mes")
ax1.set_ylabel("Producto1")
ax1.plot(data[["producto1"]])
ax1.grid()

ax2.set_title("Serie producto 2")
ax2.set_xlabel("Mes")
ax2.set_ylabel("Producto2")
ax2.plot(data[["producto2"]])
ax2.grid()

plt.show()

# %% [markdown]
# ## **3. Encontrando los componentes de una serie de tiempo**

# %% [markdown]
# En algunas ocasiones puede ser útil empezar nuestro análisis descomponiendo la serie de tiempo en sus componentes: **tendencia**, **estacionalidad** y **componente puramente aleatorio**. Una forma de hacer esto es empleando la función seasonal_decompose.

# %%
producto1_componentes_aditivos = seasonal_decompose(data[["producto1"]],model="additive")
fig = producto1_componentes_aditivos.plot()
fig.set_size_inches((8, 6))
fig.tight_layout()
print("-------------------------------------------------------------Producto 1 - aditivo-------------------------------------------------------------")
plt.show()

producto1_componentes_multiplicativos = seasonal_decompose(data[["producto1"]],model="multiplicative")
fig = producto1_componentes_multiplicativos.plot()
fig.set_size_inches((8, 6))
fig.tight_layout()
print("-------------------------------------------------------------Producto 1 - Multiplicativo-------------------------------------------------------------")
plt.show()

producto2_componentes_aditivos = seasonal_decompose(data[["producto2"]],model="additive")
fig = producto2_componentes_aditivos.plot()
fig.set_size_inches((8, 6))
fig.tight_layout()
print("-------------------------------------------------------------Producto 2 - aditivo-------------------------------------------------------------")
plt.show()

producto2_componentes_multiplicativos = seasonal_decompose(data[["producto2"]],model="multiplicative")
fig = producto2_componentes_multiplicativos.plot()
fig.set_size_inches((8, 6))
fig.tight_layout()
print("-------------------------------------------------------------Producto 2 - Multiplicativo-------------------------------------------------------------")
plt.show()
# Out:
# -------------------------------------------------------------Producto 1 - aditivo-------------------------------------------------------------
# -------------------------------------------------------------Producto 1 - Multiplicativo-------------------------------------------------------------
# -------------------------------------------------------------Producto 2 - aditivo-------------------------------------------------------------
# -------------------------------------------------------------Producto 2 - Multiplicativo-------------------------------------------------------------

# %% [markdown]
# Podemos observar el componente estacional marcado en las series de los 2 productos, una tendencia no lineal de los datos y la parte aleatoria.
#
# Es importante mencionar que esta descomposición se emplea **solo como referencia para iniciar el análisis**.
#
# Para los dos productos, el gráfico que mejor se ajusta es empleando una composición "aditiva".

# %% [markdown]
# ## **4.  Protoco de evaluación**

# %% [markdown]
# Se escogió para todos los modelos un protocolo de evaluación de ventana móvil, hallando la cantidad óptima de períodos (meses) de test (test_period) a través de optimización bayesiana.
#
# Los modelos a considerar son:
# -Promedio Móvil(pm).
# -Suavización exponencial (ETS).
# -Regresión lineal (ols).
# -Arima

# %% [markdown]
# ## **5.  Evaluación de modelos**

# %% [markdown]
# ### **5.1 Cálculo de mejor modelo e hiperparámetros a través de optimización bayesiana**

# %% [markdown]
# Se aplica un protocolo de evaluación de ventana móvil y como parámetro para la optimización bayeasiana, la métrica RMSE.  A partir de 200 iteraciones se llega a un objetivo de minimización del RMSE con los mejores hiperparámetros.

# %%
class ModelOptimization:
  def __init__(self, df):
    self.df_producto = df
    self.month_dummies = pd.get_dummies(self.df_producto.index.month, drop_first=True).set_index(self.df_producto.index)
    self.month_dummies = self.month_dummies.astype(float) # para arreglar el problema de casteo
    self.month_dummies = pd.concat([self.df_producto, self.month_dummies], axis=1)# Añadir las variables dummy al final del DataFrame original
    self.y_pred = self.df_producto.iloc[:0, 0] # Inicializar la serie de predicciones
###################################################################################################
##### 1. P R O M E D I O   M O V I L                                                          #####
###################################################################################################
  def fore_ma(self,datos,w,h):
    data=datos.copy()
    for x in range(1,h+1):
      ind = data.index[-1]
      value = ind + pd.DateOffset(months=1)
      data.loc[value]= data[-w:].mean()
    return data[-h:] 

  def promedio_movil(self, sample_size, test_period, window, min_periods):
      y_pred       = self.df_producto.iloc[:0, 0] 
      begin_sample =  len(self.df_producto) - sample_size
      for test_size in range(0, test_period):
          begin_train = begin_sample + test_size
          end_train   = len(self.df_producto) - test_period + test_size
          y_train     = self.df_producto.iloc[begin_train:end_train, 0]
          ma          = y_train.rolling(window,min_periods=min_periods).mean()
          ## Sin considerar el dato actual
          ma          = y_train.shift().rolling(window,min_periods=min_periods).mean()
          pred_1      = self.fore_ma(datos=y_train,w=window,h=1) # Solo se predice un periodo              
          y_pred.loc[pred_1.index[0]] = pred_1.values[0]
          
      y_test      = self.df_producto.iloc[-test_period:, 0]      
      rsme        = np.sqrt(mean_squared_error(y_test,y_pred ))
      self.y_pred = y_pred

      return rsme

  def objective_pm(self, trial):
    sample_size = trial.suggest_categorical('sample_size', set_sample_size)
    test_period = trial.suggest_categorical('test_period', set_test_period)
    window      = trial.suggest_int('window', 7, 10)
    min_periods = trial.suggest_int('min_periods', 2, 6)
    
    model = self.promedio_movil( sample_size=sample_size, test_period=test_period, window=window, min_periods=min_periods) 
    
    return model


###################################################################################################
##### 2. E T S                                                                                #####
###################################################################################################
  def calcular_ets(self, sample_size, test_period, error, trend, seasonal, alpha, beta, gamma):   
    y_pred       = self.df_producto.iloc[:0, 0] 
    begin_sample =  len(self.df_producto) - sample_size
    
    parameters = {}
    
    parameters['error'] = error
    if trend is not None:
      parameters['trend'] = trend
    if seasonal is not None:
      parameters['seasonal'] = seasonal

    params = {'smoothing_level': alpha,'smoothing_trend': beta,'smoothing_seasonal':gamma}

    if trend is None:
      params.pop('smoothing_trend')
    if seasonal is None:
      params.pop('smoothing_seasonal')
    
    for test_size in range(0, test_period):
      begin_train = begin_sample + test_size
      end_train   = len(self.df_producto) - test_period + test_size

      y_train   = self.month_dummies.iloc[begin_train:end_train]
      y_test    = self.month_dummies.iloc[end_train:]

      ets_model = ETSModel(endog=y_train.iloc[:, 0],error=error,trend=trend,seasonal=seasonal)

      ets_result = ets_model.fit_constrained(params)

      pred_1     = ets_result.forecast(1) # Solo se predice un periodo
      
      y_pred.loc[y_test.index[0]] = pred_1.values[0]

    y_test      = self.month_dummies.iloc[-test_period:]
    rsme        = np.sqrt(mean_squared_error(y_test.iloc[:, 0],y_pred))
    self.y_pred = y_pred

    return rsme
    
  def objective_ets(self, trial):
#   Error	Trend	Seasonal	Alpha	Beta	Gamma	RMSE
    sample_size = trial.suggest_categorical('sample_size', set_sample_size)
    test_period = trial.suggest_categorical('test_period', set_test_period)
    error       = trial.suggest_categorical('error', ['Add', 'Mul'])
    trend       = trial.suggest_categorical('trend', ['Add', 'Mul',None])
    seasonal    = trial.suggest_categorical('seasonal', ['Add', 'Mul',None])
    alpha       = trial.suggest_float('alpha', 0.01, 0.99)
    beta        = trial.suggest_float('beta', 0.01, 0.99)
    gamma       = trial.suggest_float('gamma', 0.01, 0.99)

    model = self.calcular_ets( sample_size=sample_size, test_period=test_period, error=error, trend=trend, seasonal=seasonal, alpha=alpha, beta=beta, gamma=gamma) 
    
    return model


###################################################################################################
##### 3. O L S                                                                                #####
###################################################################################################
  def calcular_ols(self, sample_size, test_period, estacionalidad, grado): 
    y_pred = self.df_producto.iloc[:0, 0] 
    begin_sample =  len(self.df_producto) - sample_size

    for test_size in range(0, test_period):
        begin_train = begin_sample + test_size
        end_train   = len(self.df_producto) - test_period + test_size
      
        #Dividimos el dataset en train y test
        y_train   = self.month_dummies.iloc[begin_train:end_train, 0]
        y_test    = self.month_dummies.iloc[end_train:, 0]
        
        ln_test   = np.linspace(len(y_train) + 1, len(self.df_producto), len(y_test))
        X_test    = np.vander(ln_test, N=grado+1)

        ln_train  = np.linspace(1, y_train.shape[0], y_train.shape[0])
        X_train   = np.vander(ln_train, N=grado+1)

        if estacionalidad == 'Si':        
            X_train = np.concatenate([X_train, self.month_dummies.iloc[begin_train:end_train, 3:].values], axis=1)
            X_test  = np.concatenate([X_test,  self.month_dummies.iloc[end_train:, 3:].values],  axis=1)

        lin    = sm.OLS(y_train, X_train).fit()

        pred_1 = lin.predict(X_test)
        
        y_pred.loc[y_test.index[0]] = pred_1[0]

    y_test      = self.month_dummies.iloc[-test_period:, 0]       
    rsme        = np.sqrt(mean_squared_error(y_test, y_pred))
    self.y_pred = y_pred

    return rsme
  
  def objective_ols(self, trial):
    sample_size    = trial.suggest_categorical('sample_size', set_sample_size)
    test_period    = trial.suggest_categorical('test_period', set_test_period)
    estacionalidad = trial.suggest_categorical('Estacionalidad', ['Si', 'No'])
    grado          = trial.suggest_int('grado', 2, 30)
    
    model = self.calcular_ols(sample_size=sample_size, test_period=test_period, estacionalidad=estacionalidad, grado=grado) 
    
    return model
  
###################################################################################################
##### 4. A R I M A                                                                            #####
###################################################################################################
  def calcular_arima(self, sample_size, test_period, p, d, q):
    y_pred = self.df_producto.iloc[:0,0]

    begin_sample =  len(self.df_producto) - sample_size

    for test_size in range(0, test_period):
#     train_len = len(self.df_producto) - test_period + i
      begin_train = begin_sample + test_size
      end_train   = len(self.df_producto) - test_period + test_size
      
      #Dividimos el dataset en train y test
      y_train = self.df_producto.iloc[begin_train:end_train]
      y_test  = self.df_producto.iloc[end_train:]

      # Ajusta el modelo ARIMA con los parámetros sugeridos
      model = ARIMA(y_train, order=(p, d, q))
      model_fit = model.fit()
    
      # Realiza predicciones en el conjunto de prueba
      pred_1 = model_fit.predict(start=len(y_train), end=len(y_train) + 1, dynamic=False)

      y_pred.loc[y_test.index[0]] = pred_1.values[0]
    
    y_test      = self.df_producto.iloc[-test_period:]
    rsme        = np.sqrt(mean_squared_error(y_test, y_pred))
    self.y_pred = y_pred

    return rsme

  def objective_arima(self, trial):
    sample_size = trial.suggest_categorical('sample_size', set_sample_size)
    test_period = trial.suggest_categorical('test_period', set_test_period)
    p           = trial.suggest_int('p', 0, 3)  # Orden autorregresivo
    d           = trial.suggest_int('d', 0, 3)  # Orden de diferenciación
    q           = trial.suggest_int('q', 0, 3)  # Orden de media móvil
    model = self.calcular_arima(sample_size=sample_size, test_period=test_period,p=p, d=d, q=q)
    
    return model

# %%
column_names = data.columns.tolist()
column_names.remove('indice')
column_names.remove('corte')
print(column_names)

global set_sample_size
global set_test_period
# Out:
# ['producto1', 'producto2']

# %% [markdown]
# Como el modelo se va a ejecutar varias veces, por optimizacion de codigo define como una funcion para que peuda ser referenciada y no escribir multiples veces el mismo codigo.
#
# En este se recorre para cada producto, la optimizacion bayesiana de:
# - Promedio Movil
# - ETS
# - OLS
# - Arima
#
# los mejores resultados para cada modelo se almacenan en un dataframe que será utilizado en pasos posteriores

# %%
def run_model(trials): 
    global set_sample_size
    global set_test_period
    global  df_products
    
    results = []

    for producto in column_names:

        product_row = df_products[df_products['producto'] == producto]

        if not product_row.empty:
            best_params     = product_row.iloc[0]['best_params']
            set_sample_size = [best_params['sample_size']]
            set_test_period = [best_params['test_period']]            
        else:
            set_sample_size = global_size
            set_test_period = global_period

        model_optimization = ModelOptimization(data[[producto]])

        study_pm = optuna.create_study(direction='minimize')
        study_pm.optimize(model_optimization.objective_pm, n_trials=trials)
        results.append({
        'producto': producto,
        'tipo': 'Promedio movil',
        'rmse': study_pm.best_value,
        'best_params': study_pm.best_params })

        study_ets = optuna.create_study(direction='minimize')
        study_ets.optimize(model_optimization.objective_ets, n_trials=trials)
        results.append({
        'producto': producto,
        'tipo': 'ETS',
        'rmse': study_ets.best_value,
        'best_params': study_ets.best_params })

        study_ols = optuna.create_study(direction='minimize')
        study_ols.optimize(model_optimization.objective_ols, n_trials=trials)
        results.append({
        'producto': producto,
        'tipo': 'OLS',
        'rmse': study_ols.best_value,
        'best_params': study_ols.best_params })

        study_arima = optuna.create_study(direction='minimize')
        study_arima.optimize(model_optimization.objective_arima, n_trials=trials)
        results.append({
        'producto': producto,
        'tipo': 'ARIMA',
        'rmse': study_arima.best_value,
        'best_params': study_arima.best_params })
        
        print("------------------------------------------------------------------")    
    
    df_results = pd.DataFrame(results, columns=['producto', 'tipo', 'rmse', 'best_params'])
    df_results.sort_values(by=['producto', 'rmse'], ascending=[True, True],inplace=True)
        
    for index, row in df_results.iterrows():
        print(f"Producto: {row['producto']}")
        print(f"Tipo: {row['tipo']}")
        print(f"RMSE: {row['rmse']}")
        print(f"Best Params: {row['best_params']}")
        print("--------------------------------------------------")
    
    return df_results

# %% [markdown]
# Se ejecuta el modelo para identificar los 2 primeros hiperparametros, Tamaño de la ventana (T), desde donde vamos obtener el T-H (In-sample) y H (Out-Sample)
#
# Se establecen como opciones para T de 48 períodos (4 años), 72 períodos (6 años), 96 períodos (8 años)  y 127 (Muestra completa)
#
# En relacion a los datos de Out_Sample que se van a utilizar para test, se manejan parámetros de 6 meses, 12 meses, 18 meses y 24 meses, con estos valores se realizan las diferentes validaciones del modelo
#
# Se establece 200 muestras para realizar las ejecuciones de optimización bayesiana

# %%
global_size   = [48, 72, 96, 127]
global_period = [6, 12, 18, 24]
trials        = 200
df_products = pd.DataFrame(columns=['producto', 'tipo', 'rmse', 'best_params'])

df_results    = run_model(trials)
# Out:
# [I 2024-09-17 11:13:03,756] A new study created in memory with name: no-name-8509aba1-37cb-44ac-9750-c45d3b4751c8
# [I 2024-09-17 11:13:03,972] Trial 0 finished with value: 36.02731366835366 and parameters: {'sample_size': 96, 'test_period': 24, 'window': 8, 'min_periods': 6}. Best is trial 0 with value: 36.02731366835366.
# [I 2024-09-17 11:13:04,025] Trial 1 finished with value: 36.40560075214798 and parameters: {'sample_size': 48, 'test_period': 12, 'window': 9, 'min_periods': 4}. Best is trial 0 with value: 36.02731366835366.
# [I 2024-09-17 11:13:04,118] Trial 2 finished with value: 36.17612478383117 and parameters: {'sample_size': 96, 'test_period': 18, 'window': 8, 'min_periods': 4}. Best is trial 0 with value: 36.02731366835366.
# [I 2024-09-17 11:13:04,169] Trial 3 finished with value: 25.429264297321534 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 10, 'min_periods': 5}. Best is trial 3 with value: 25.429264297321534.
# [I 2024-09-17 11:13:04,332] Trial 4 finished with value: 36.02731366835366 and parameters: {'sample_size': 48, 'test_period': 24, 'window': 8, 'min_periods': 5}. Best is trial 3 with value: 25.429264297321534.
# [I 2024-09-17 11:13:04,376] Trial 5 finished with value: 25.429264297321534 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 10, 'min_periods': 4}. Best is trial 3 with value: 25.429264297321534.
# [I 2024-09-17 11:13:04,471] Trial 6 finished with value: 44.10042170545523 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 10, 'min_periods': 3}. Best is trial 3 with value: 25.429264297321534.
# [I 2024-09-17 11:13:04,569] Trial 7 finished with value: 39.91134891262945 and parameters: {'sample_size': 48, 'test_period': 24, 'window': 9, 'min_periods': 6}. Best is trial 3 with value: 25.429264297321534.
# [I 2024-09-17 11:13:04,601] Trial 8 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:04,679] Trial 9 finished with value: 44.10042170545523 and parameters: {'sample_size': 96, 'test_period': 18, 'window': 10, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:04,757] Trial 10 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:04,833] Trial 11 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:04,907] Trial 12 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:04,968] Trial 13 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,045] Trial 14 finished with value: 28.461375751786118 and parameters: {'sample_size': 96, 'test_period': 12, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,102] Trial 15 finished with value: 19.360260719899816 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 8, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,157] Trial 16 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,215] Trial 17 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,295] Trial 18 finished with value: 36.40560075214798 and parameters: {'sample_size': 72, 'test_period': 12, 'window': 9, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,354] Trial 19 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,409] Trial 20 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,467] Trial 21 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,522] Trial 22 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,581] Trial 23 finished with value: 19.360260719899816 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 8, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,641] Trial 24 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,703] Trial 25 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,785] Trial 26 finished with value: 32.41589041425786 and parameters: {'sample_size': 127, 'test_period': 12, 'window': 8, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:05,911] Trial 27 finished with value: 32.11515277810209 and parameters: {'sample_size': 48, 'test_period': 24, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,012] Trial 28 finished with value: 36.17612478383117 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 8, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,136] Trial 29 finished with value: 32.11515277810209 and parameters: {'sample_size': 96, 'test_period': 24, 'window': 7, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,194] Trial 30 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,253] Trial 31 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,312] Trial 32 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,389] Trial 33 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,465] Trial 34 finished with value: 22.212287548155793 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 9, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,560] Trial 35 finished with value: 28.461375751786118 and parameters: {'sample_size': 48, 'test_period': 12, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,621] Trial 36 finished with value: 19.360260719899816 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,729] Trial 37 finished with value: 32.23909488459876 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,854] Trial 38 finished with value: 36.02731366835366 and parameters: {'sample_size': 127, 'test_period': 24, 'window': 8, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,919] Trial 39 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:06,996] Trial 40 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,074] Trial 41 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,152] Trial 42 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,233] Trial 43 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,342] Trial 44 finished with value: 32.23909488459876 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 7, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,401] Trial 45 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,465] Trial 46 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,546] Trial 47 finished with value: 28.461375751786118 and parameters: {'sample_size': 72, 'test_period': 12, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,608] Trial 48 finished with value: 25.429264297321534 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 10, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,737] Trial 49 finished with value: 39.91134891262945 and parameters: {'sample_size': 96, 'test_period': 24, 'window': 9, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,800] Trial 50 finished with value: 19.360260719899816 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 8, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,862] Trial 51 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,921] Trial 52 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:07,981] Trial 53 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,051] Trial 54 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,136] Trial 55 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,286] Trial 56 finished with value: 32.23909488459876 and parameters: {'sample_size': 96, 'test_period': 18, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,357] Trial 57 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,441] Trial 58 finished with value: 28.461375751786118 and parameters: {'sample_size': 72, 'test_period': 12, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,504] Trial 59 finished with value: 19.360260719899816 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,564] Trial 60 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,630] Trial 61 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,700] Trial 62 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,764] Trial 63 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,832] Trial 64 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:08,963] Trial 65 finished with value: 32.11515277810209 and parameters: {'sample_size': 72, 'test_period': 24, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,024] Trial 66 finished with value: 19.360260719899816 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 8, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,087] Trial 67 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,153] Trial 68 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,262] Trial 69 finished with value: 40.07668038696318 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 9, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,376] Trial 70 finished with value: 28.461375751786118 and parameters: {'sample_size': 96, 'test_period': 12, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,449] Trial 71 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,513] Trial 72 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,575] Trial 73 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,640] Trial 74 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,704] Trial 75 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,767] Trial 76 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,833] Trial 77 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:09,963] Trial 78 finished with value: 32.11515277810209 and parameters: {'sample_size': 72, 'test_period': 24, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,027] Trial 79 finished with value: 19.360260719899816 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,091] Trial 80 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,151] Trial 81 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,214] Trial 82 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,277] Trial 83 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,340] Trial 84 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,405] Trial 85 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,518] Trial 86 finished with value: 32.23909488459876 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,584] Trial 87 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,674] Trial 88 finished with value: 36.40560075214798 and parameters: {'sample_size': 96, 'test_period': 12, 'window': 9, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,740] Trial 89 finished with value: 25.429264297321534 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 10, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,804] Trial 90 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,868] Trial 91 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,934] Trial 92 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:10,998] Trial 93 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,064] Trial 94 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,131] Trial 95 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,261] Trial 96 finished with value: 32.11515277810209 and parameters: {'sample_size': 127, 'test_period': 24, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,325] Trial 97 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,417] Trial 98 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,559] Trial 99 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,627] Trial 100 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,694] Trial 101 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,765] Trial 102 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,827] Trial 103 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:11,944] Trial 104 finished with value: 32.23909488459876 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,009] Trial 105 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,095] Trial 106 finished with value: 28.461375751786118 and parameters: {'sample_size': 72, 'test_period': 12, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,160] Trial 107 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,236] Trial 108 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,304] Trial 109 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,373] Trial 110 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,444] Trial 111 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,511] Trial 112 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,578] Trial 113 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,646] Trial 114 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,780] Trial 115 finished with value: 32.11515277810209 and parameters: {'sample_size': 127, 'test_period': 24, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,849] Trial 116 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,917] Trial 117 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:12,984] Trial 118 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,050] Trial 119 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,114] Trial 120 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,181] Trial 121 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,249] Trial 122 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,315] Trial 123 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,382] Trial 124 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,493] Trial 125 finished with value: 32.23909488459876 and parameters: {'sample_size': 96, 'test_period': 18, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,558] Trial 126 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,653] Trial 127 finished with value: 28.461375751786118 and parameters: {'sample_size': 127, 'test_period': 12, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,741] Trial 128 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,827] Trial 129 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:13,925] Trial 130 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,005] Trial 131 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,070] Trial 132 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,139] Trial 133 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,290] Trial 134 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,359] Trial 135 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,425] Trial 136 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,557] Trial 137 finished with value: 32.11515277810209 and parameters: {'sample_size': 72, 'test_period': 24, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,624] Trial 138 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,692] Trial 139 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,770] Trial 140 finished with value: 25.429264297321534 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 10, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,859] Trial 141 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:14,933] Trial 142 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,002] Trial 143 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,070] Trial 144 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,157] Trial 145 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,250] Trial 146 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,390] Trial 147 finished with value: 32.23909488459876 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,465] Trial 148 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,533] Trial 149 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,629] Trial 150 finished with value: 28.461375751786118 and parameters: {'sample_size': 72, 'test_period': 12, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,699] Trial 151 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,769] Trial 152 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,861] Trial 153 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:15,930] Trial 154 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,007] Trial 155 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,075] Trial 156 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,146] Trial 157 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,220] Trial 158 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,289] Trial 159 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,420] Trial 160 finished with value: 39.91134891262945 and parameters: {'sample_size': 72, 'test_period': 24, 'window': 9, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,490] Trial 161 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,556] Trial 162 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,625] Trial 163 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,696] Trial 164 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,766] Trial 165 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,860] Trial 166 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:16,977] Trial 167 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,080] Trial 168 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,169] Trial 169 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,265] Trial 170 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,360] Trial 171 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,430] Trial 172 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,503] Trial 173 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,575] Trial 174 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,644] Trial 175 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,762] Trial 176 finished with value: 32.23909488459876 and parameters: {'sample_size': 72, 'test_period': 18, 'window': 7, 'min_periods': 3}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,835] Trial 177 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:17,916] Trial 178 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,030] Trial 179 finished with value: 28.461375751786118 and parameters: {'sample_size': 96, 'test_period': 12, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,101] Trial 180 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,187] Trial 181 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,261] Trial 182 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,335] Trial 183 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,420] Trial 184 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,497] Trial 185 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,574] Trial 186 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,647] Trial 187 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,724] Trial 188 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,799] Trial 189 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:18,943] Trial 190 finished with value: 32.11515277810209 and parameters: {'sample_size': 72, 'test_period': 24, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,021] Trial 191 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,126] Trial 192 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,222] Trial 193 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,335] Trial 194 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,439] Trial 195 finished with value: 22.212287548155793 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 9, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,524] Trial 196 finished with value: 17.011191792920002 and parameters: {'sample_size': 127, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,604] Trial 197 finished with value: 17.011191792920002 and parameters: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,685] Trial 198 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,765] Trial 199 finished with value: 17.011191792920002 and parameters: {'sample_size': 48, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 8 with value: 17.011191792920002.
# [I 2024-09-17 11:13:19,767] A new study created in memory with name: no-name-ccaf13dd-496f-4cd3-80be-ceaca6bf7139
# [I 2024-09-17 11:13:24,460] Trial 0 finished with value: 9.134019377621799 and parameters: {'sample_size': 96, 'test_period': 24, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.2846813592499422, 'beta': 0.34874653983256176, 'gamma': 0.7472444376321445}. Best is trial 0 with value: 9.134019377621799.
# [I 2024-09-17 11:13:34,068] Trial 1 finished with value: 11.96233279604454 and parameters: {'sample_size': 96, 'test_period': 18, 'error': 'Add', 'trend': 'Mul', 'seasonal': 'Add', 'alpha': 0.6570113566930778, 'beta': 0.6986266828453419, 'gamma': 0.19294696086226995}. Best is trial 0 with value: 9.134019377621799.
# [I 2024-09-17 11:13:38,265] Trial 2 finished with value: 14.071243911877955 and parameters: {'sample_size': 48, 'test_period': 24, 'error': 'Add', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.9012737245246598, 'beta': 0.14086058889406705, 'gamma': 0.9423304842222067}. Best is trial 0 with value: 9.134019377621799.
# [I 2024-09-17 11:13:39,168] Trial 3 finished with value: 14.511454717987883 and parameters: {'sample_size': 96, 'test_period': 18, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.08428449237209942, 'beta': 0.39669923491564196, 'gamma': 0.34559346642888933}. Best is trial 0 with value: 9.134019377621799.
# [I 2024-09-17 11:13:40,135] Trial 4 finished with value: 8.574395748483582 and parameters: {'sample_size': 72, 'test_period': 6, 'error': 'Add', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.48105325086830303, 'beta': 0.6453197466607967, 'gamma': 0.4526414828818782}. Best is trial 4 with value: 8.574395748483582.
# [I 2024-09-17 11:13:40,637] Trial 5 finished with value: 10.981582044494573 and parameters: {'sample_size': 96, 'test_period': 12, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.940034111156403, 'beta': 0.8837568159142648, 'gamma': 0.16326788438038128}. Best is trial 4 with value: 8.574395748483582.
# [I 2024-09-17 11:13:41,183] Trial 6 finished with value: 42.364344336482375 and parameters: {'sample_size': 72, 'test_period': 6, 'error': 'Add', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.07987792166155713, 'beta': 0.5521179830081709, 'gamma': 0.6520321289209965}. Best is trial 4 with value: 8.574395748483582.
# [I 2024-09-17 11:13:44,671] Trial 7 finished with value: 12.800098754504553 and parameters: {'sample_size': 72, 'test_period': 12, 'error': 'Add', 'trend': 'Mul', 'seasonal': 'Add', 'alpha': 0.9254544217042083, 'beta': 0.45777181291218894, 'gamma': 0.6514456851653716}. Best is trial 4 with value: 8.574395748483582.
# [I 2024-09-17 11:13:45,480] Trial 8 finished with value: 8.568123445085245 and parameters: {'sample_size': 127, 'test_period': 18, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.304843310582164, 'beta': 0.4817290010242293, 'gamma': 0.09687796790819213}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:51,328] Trial 9 finished with value: 16.03794001540051 and parameters: {'sample_size': 96, 'test_period': 24, 'error': 'Mul', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.9298616013792739, 'beta': 0.34305230647003965, 'gamma': 0.6993692939818422}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:52,045] Trial 10 finished with value: 9.655254847991184 and parameters: {'sample_size': 127, 'test_period': 18, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.37082496396964204, 'beta': 0.11727266659163182, 'gamma': 0.06890718767109409}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:52,293] Trial 11 finished with value: 9.54131643155108 and parameters: {'sample_size': 127, 'test_period': 6, 'error': 'Mul', 'trend': None, 'seasonal': None, 'alpha': 0.566218802492362, 'beta': 0.695827116311158, 'gamma': 0.3636411706307594}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:53,263] Trial 12 finished with value: 9.078659749339115 and parameters: {'sample_size': 127, 'test_period': 6, 'error': 'Mul', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.35293174987894543, 'beta': 0.6490215834738831, 'gamma': 0.40811707061492764}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:53,739] Trial 13 finished with value: 13.867498306330688 and parameters: {'sample_size': 72, 'test_period': 18, 'error': 'Add', 'trend': None, 'seasonal': None, 'alpha': 0.6596408755844754, 'beta': 0.9239833421169221, 'gamma': 0.022039767633234994}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:55,778] Trial 14 finished with value: 10.034813474432067 and parameters: {'sample_size': 48, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Add', 'alpha': 0.19237942557037974, 'beta': 0.7722826368286271, 'gamma': 0.5126606475069581}. Best is trial 8 with value: 8.568123445085245.
# [I 2024-09-17 11:13:57,149] Trial 15 finished with value: 7.444073070565689 and parameters: {'sample_size': 127, 'test_period': 6, 'error': 'Mul', 'trend': 'Mul', 'seasonal': 'Mul', 'alpha': 0.4910519417266432, 'beta': 0.5255650038061296, 'gamma': 0.2313322533335908}. Best is trial 15 with value: 7.444073070565689.
# [I 2024-09-17 11:13:57,961] Trial 16 finished with value: 8.818069726660319 and parameters: {'sample_size': 127, 'test_period': 18, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.45533355192805974, 'beta': 0.24635618849689334, 'gamma': 0.23487386551631595}. Best is trial 15 with value: 7.444073070565689.
# ...
# [I 2024-09-17 11:27:50,848] Trial 131 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:27:54,476] Trial 132 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:27:57,997] Trial 133 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:01,659] Trial 134 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:05,213] Trial 135 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:08,803] Trial 136 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:12,383] Trial 137 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:15,069] Trial 138 finished with value: 8.9606622998177 and parameters: {'sample_size': 96, 'test_period': 12, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:16,504] Trial 139 finished with value: 9.778702380372344 and parameters: {'sample_size': 96, 'test_period': 6, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:20,264] Trial 140 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:24,102] Trial 141 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:27,702] Trial 142 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:31,328] Trial 143 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:35,683] Trial 144 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:39,262] Trial 145 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:42,825] Trial 146 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 11:28:46,302] Trial 147 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:43:54,234] Trial 148 finished with value: 8.835714241399304 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:43:59,112] Trial 149 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:03,876] Trial 150 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:07,566] Trial 151 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:11,421] Trial 152 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:15,698] Trial 153 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:18,386] Trial 154 finished with value: 8.614475170237283 and parameters: {'sample_size': 72, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:21,857] Trial 155 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:25,714] Trial 156 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:29,509] Trial 157 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:33,452] Trial 158 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:36,373] Trial 159 finished with value: 8.144745014974989 and parameters: {'sample_size': 96, 'test_period': 18, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:41,067] Trial 160 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:44,885] Trial 161 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:48,645] Trial 162 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:52,182] Trial 163 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:44:56,173] Trial 164 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:00,403] Trial 165 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:04,170] Trial 166 finished with value: 8.9606622998177 and parameters: {'sample_size': 96, 'test_period': 12, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:10,546] Trial 167 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:14,258] Trial 168 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:15,684] Trial 169 finished with value: 9.778702380372344 and parameters: {'sample_size': 96, 'test_period': 6, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:19,605] Trial 170 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:23,426] Trial 171 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:27,364] Trial 172 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:31,259] Trial 173 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:35,090] Trial 174 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:41,298] Trial 175 finished with value: 8.835714241399304 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:44,890] Trial 176 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:48,368] Trial 177 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:50,843] Trial 178 finished with value: 8.614475170237283 and parameters: {'sample_size': 72, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:54,305] Trial 179 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:45:57,825] Trial 180 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:01,276] Trial 181 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:05,005] Trial 182 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:08,497] Trial 183 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:11,984] Trial 184 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:15,604] Trial 185 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:17,025] Trial 186 finished with value: 41.93047625135783 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 0, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:20,493] Trial 187 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:23,991] Trial 188 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:27,404] Trial 189 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:30,169] Trial 190 finished with value: 8.144745014974989 and parameters: {'sample_size': 96, 'test_period': 18, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:33,593] Trial 191 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:37,069] Trial 192 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:40,527] Trial 193 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:44,004] Trial 194 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:47,484] Trial 195 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:50,960] Trial 196 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:54,381] Trial 197 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:46:56,857] Trial 198 finished with value: 8.9606622998177 and parameters: {'sample_size': 96, 'test_period': 12, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# [I 2024-09-17 12:47:00,351] Trial 199 finished with value: 8.102316687773902 and parameters: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}. Best is trial 89 with value: 8.102316687773902.
# ------------------------------------------------------------------
# Producto: producto1
# Tipo: ETS
# RMSE: 5.407414813535559
# Best Params: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.7558186286611535, 'beta': 0.0918466590467808, 'gamma': 0.33754452507352734}
# --------------------------------------------------
# Producto: producto1
# Tipo: ARIMA
# RMSE: 5.438842329971916
# Best Params: {'sample_size': 48, 'test_period': 6, 'p': 3, 'd': 1, 'q': 3}
# --------------------------------------------------
# Producto: producto1
# Tipo: OLS
# RMSE: 5.694295696809006
# Best Params: {'sample_size': 48, 'test_period': 6, 'Estacionalidad': 'Si', 'grado': 4}
# --------------------------------------------------
# Producto: producto1
# Tipo: Promedio movil
# RMSE: 17.011191792920002
# Best Params: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}
# --------------------------------------------------
# Producto: producto2
# Tipo: ETS
# RMSE: 7.197986716771442
# Best Params: {'sample_size': 127, 'test_period': 24, 'error': 'Add', 'trend': 'Add', 'seasonal': None, 'alpha': 0.9720587519832363, 'beta': 0.6880495424146043, 'gamma': 0.4105678682129933}
# --------------------------------------------------
# Producto: producto2
# Tipo: ARIMA
# RMSE: 8.102316687773902
# Best Params: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}
# --------------------------------------------------
# Producto: producto2
# Tipo: OLS
# RMSE: 31.228670865439604
# Best Params: {'sample_size': 127, 'test_period': 6, 'Estacionalidad': 'No', 'grado': 2}
# --------------------------------------------------
# Producto: producto2
# Tipo: Promedio movil
# RMSE: 33.822873448499045
# Best Params: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}
# --------------------------------------------------

# %% [markdown]
# Se listan los resultados obtenidos para cada producto y tipo de modelo. Se muestra el RMSE y los mejores parámetros obtenidos para cada modelo.

# %%
for index, row in df_results.iterrows():
    print(f"Producto: {row['producto']}")
    print(f"Tipo: {row['tipo']}")
    print(f"RMSE: {row['rmse']}")
    print(f"Best Params: {row['best_params']}")
    print("--------------------------------------------------")
# Out:
# Producto: producto1
# Tipo: ETS
# RMSE: 5.407414813535559
# Best Params: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.7558186286611535, 'beta': 0.0918466590467808, 'gamma': 0.33754452507352734}
# --------------------------------------------------
# Producto: producto1
# Tipo: ARIMA
# RMSE: 5.438842329971916
# Best Params: {'sample_size': 48, 'test_period': 6, 'p': 3, 'd': 1, 'q': 3}
# --------------------------------------------------
# Producto: producto1
# Tipo: OLS
# RMSE: 5.694295696809006
# Best Params: {'sample_size': 48, 'test_period': 6, 'Estacionalidad': 'Si', 'grado': 4}
# --------------------------------------------------
# Producto: producto1
# Tipo: Promedio movil
# RMSE: 17.011191792920002
# Best Params: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}
# --------------------------------------------------
# Producto: producto2
# Tipo: ETS
# RMSE: 7.197986716771442
# Best Params: {'sample_size': 127, 'test_period': 24, 'error': 'Add', 'trend': 'Add', 'seasonal': None, 'alpha': 0.9720587519832363, 'beta': 0.6880495424146043, 'gamma': 0.4105678682129933}
# --------------------------------------------------
# Producto: producto2
# Tipo: ARIMA
# RMSE: 8.102316687773902
# Best Params: {'sample_size': 96, 'test_period': 24, 'p': 3, 'd': 0, 'q': 1}
# --------------------------------------------------
# Producto: producto2
# Tipo: OLS
# RMSE: 31.228670865439604
# Best Params: {'sample_size': 127, 'test_period': 6, 'Estacionalidad': 'No', 'grado': 2}
# --------------------------------------------------
# Producto: producto2
# Tipo: Promedio movil
# RMSE: 33.822873448499045
# Best Params: {'sample_size': 72, 'test_period': 6, 'window': 7, 'min_periods': 5}
# --------------------------------------------------

# %% [markdown]
# Se filtra el DataFrame para conservar solo una entrada para cada producto con el menor RMSE para seleccionar dentro de la evaluacion los mejores parametros para T y T-H

# %%
df_products = df_results.loc[df_results.groupby('producto')['rmse'].idxmin()]

# %% [markdown]
# Con los valores ya fijos para cada producto, se procede a ejecutar el modelo de nuevo, para evaluar todos los modelos con el mismo criterio de T y T-H, de esta manera se evaluan los modelos en igualdad de condiciones
#
# El modelo se ejecuta con un trial de 200, para realizar el analisis bayesiano e identificar los hiperparametros para los mejores RSME/Modelo

# %%
trials  = 200

df_results = run_model(trials)
# Out:
# [I 2024-09-17 12:47:00,420] A new study created in memory with name: no-name-a9a436c1-8a78-4603-bbbc-0f6ba8e1118d
# [I 2024-09-17 12:47:00,442] Trial 0 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 3}. Best is trial 0 with value: 19.360260719899816.
# [I 2024-09-17 12:47:00,465] Trial 1 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 0 with value: 19.360260719899816.
# [I 2024-09-17 12:47:00,487] Trial 2 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 2}. Best is trial 0 with value: 19.360260719899816.
# [I 2024-09-17 12:47:00,512] Trial 3 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 3}. Best is trial 0 with value: 19.360260719899816.
# [I 2024-09-17 12:47:00,532] Trial 4 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 2}. Best is trial 0 with value: 19.360260719899816.
# [I 2024-09-17 12:47:00,557] Trial 5 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,599] Trial 6 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,631] Trial 7 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,651] Trial 8 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,671] Trial 9 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,694] Trial 10 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,717] Trial 11 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,739] Trial 12 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,762] Trial 13 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,783] Trial 14 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,807] Trial 15 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,828] Trial 16 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,851] Trial 17 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,872] Trial 18 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,893] Trial 19 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,915] Trial 20 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,937] Trial 21 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,956] Trial 22 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,978] Trial 23 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:00,998] Trial 24 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,021] Trial 25 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,042] Trial 26 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,063] Trial 27 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,085] Trial 28 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,107] Trial 29 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,129] Trial 30 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,151] Trial 31 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,172] Trial 32 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,194] Trial 33 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,217] Trial 34 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,239] Trial 35 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,261] Trial 36 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,281] Trial 37 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,307] Trial 38 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,329] Trial 39 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,351] Trial 40 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,373] Trial 41 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,397] Trial 42 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,418] Trial 43 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,440] Trial 44 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,464] Trial 45 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,487] Trial 46 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,508] Trial 47 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,531] Trial 48 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,552] Trial 49 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,576] Trial 50 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,598] Trial 51 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,622] Trial 52 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,645] Trial 53 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,666] Trial 54 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,688] Trial 55 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,712] Trial 56 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,735] Trial 57 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,757] Trial 58 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,779] Trial 59 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,803] Trial 60 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,826] Trial 61 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,851] Trial 62 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,873] Trial 63 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,895] Trial 64 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,917] Trial 65 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,939] Trial 66 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,960] Trial 67 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:01,982] Trial 68 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,005] Trial 69 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,028] Trial 70 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,051] Trial 71 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,074] Trial 72 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,096] Trial 73 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,118] Trial 74 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,141] Trial 75 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,162] Trial 76 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,184] Trial 77 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,213] Trial 78 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,237] Trial 79 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,259] Trial 80 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,284] Trial 81 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,307] Trial 82 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,332] Trial 83 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,357] Trial 84 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,391] Trial 85 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,427] Trial 86 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,451] Trial 87 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,475] Trial 88 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,497] Trial 89 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,520] Trial 90 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,544] Trial 91 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,568] Trial 92 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,590] Trial 93 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,611] Trial 94 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,632] Trial 95 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,655] Trial 96 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,677] Trial 97 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,701] Trial 98 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,723] Trial 99 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,746] Trial 100 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,769] Trial 101 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,794] Trial 102 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,815] Trial 103 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,837] Trial 104 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,860] Trial 105 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,884] Trial 106 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,906] Trial 107 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,930] Trial 108 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,954] Trial 109 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,977] Trial 110 finished with value: 19.360260719899816 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 8, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:02,999] Trial 111 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,024] Trial 112 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,046] Trial 113 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,069] Trial 114 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,091] Trial 115 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,115] Trial 116 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,139] Trial 117 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,162] Trial 118 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,184] Trial 119 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,208] Trial 120 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,233] Trial 121 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,262] Trial 122 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,285] Trial 123 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,309] Trial 124 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,335] Trial 125 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,357] Trial 126 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,383] Trial 127 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,406] Trial 128 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,431] Trial 129 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,455] Trial 130 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,479] Trial 131 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,503] Trial 132 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,526] Trial 133 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,551] Trial 134 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,574] Trial 135 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,597] Trial 136 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,619] Trial 137 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,644] Trial 138 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,668] Trial 139 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,692] Trial 140 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,714] Trial 141 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,739] Trial 142 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,761] Trial 143 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,784] Trial 144 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,807] Trial 145 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,833] Trial 146 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,857] Trial 147 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,880] Trial 148 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,905] Trial 149 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,929] Trial 150 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,952] Trial 151 finished with value: 22.212287548155793 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 9, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:03,976] Trial 152 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,001] Trial 153 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,024] Trial 154 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,049] Trial 155 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,072] Trial 156 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,096] Trial 157 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,120] Trial 158 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,143] Trial 159 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,166] Trial 160 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 2}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,190] Trial 161 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,214] Trial 162 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,238] Trial 163 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,266] Trial 164 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,297] Trial 165 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,320] Trial 166 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,346] Trial 167 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,370] Trial 168 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,393] Trial 169 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,417] Trial 170 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,440] Trial 171 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,463] Trial 172 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,488] Trial 173 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,510] Trial 174 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,535] Trial 175 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,559] Trial 176 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,583] Trial 177 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,605] Trial 178 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,631] Trial 179 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,655] Trial 180 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,678] Trial 181 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,703] Trial 182 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,726] Trial 183 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,749] Trial 184 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,774] Trial 185 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,797] Trial 186 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,822] Trial 187 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,848] Trial 188 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,870] Trial 189 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,896] Trial 190 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,920] Trial 191 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,946] Trial 192 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,970] Trial 193 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:04,993] Trial 194 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:05,020] Trial 195 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 6}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:05,042] Trial 196 finished with value: 25.429264297321534 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 10, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:05,067] Trial 197 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 3}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:05,092] Trial 198 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 5}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:05,118] Trial 199 finished with value: 17.011191792920002 and parameters: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}. Best is trial 5 with value: 17.011191792920002.
# [I 2024-09-17 12:47:05,119] A new study created in memory with name: no-name-fa89cb75-61cc-435c-931f-652c1b944cb1
# [I 2024-09-17 12:47:05,537] Trial 0 finished with value: 7.051064576312876 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.36487159585175344, 'beta': 0.14393398889844683, 'gamma': 0.6551138678145816}. Best is trial 0 with value: 7.051064576312876.
# [I 2024-09-17 12:47:06,220] Trial 1 finished with value: 14.90324388780181 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Add', 'alpha': 0.5422385857080196, 'beta': 0.40358545647011124, 'gamma': 0.9645400014468353}. Best is trial 0 with value: 7.051064576312876.
# [I 2024-09-17 12:47:06,283] Trial 2 finished with value: 9.363385358691508 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Mul', 'trend': None, 'seasonal': None, 'alpha': 0.5877406660172503, 'beta': 0.9074751575980061, 'gamma': 0.8015846887792406}. Best is trial 0 with value: 7.051064576312876.
# [I 2024-09-17 12:47:06,666] Trial 3 finished with value: 7.836773212178018 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Mul', 'trend': 'Mul', 'seasonal': 'Mul', 'alpha': 0.6181647280742762, 'beta': 0.1656773398384726, 'gamma': 0.19371789404071266}. Best is trial 0 with value: 7.051064576312876.
# [I 2024-09-17 12:47:06,945] Trial 4 finished with value: 110.6271283693947 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Mul', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.021613112080007303, 'beta': 0.939156371637198, 'gamma': 0.3068952473849352}. Best is trial 0 with value: 7.051064576312876.
# [I 2024-09-17 12:47:07,192] Trial 5 finished with value: 9.080228485453466 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': None, 'seasonal': 'Add', 'alpha': 0.4636099413459269, 'beta': 0.5618971938583326, 'gamma': 0.6495130821472896}. Best is trial 0 with value: 7.051064576312876.
# [I 2024-09-17 12:47:07,959] Trial 6 finished with value: 6.615075468116631 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.06119114557237186, 'beta': 0.5608162009726452, 'gamma': 0.5757964262367374}. Best is trial 6 with value: 6.615075468116631.
# [I 2024-09-17 12:47:09,213] Trial 7 finished with value: 14.015356505715658 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Mul', 'trend': 'Mul', 'seasonal': 'Mul', 'alpha': 0.316961570966585, 'beta': 0.8768905704439872, 'gamma': 0.8245726670384212}. Best is trial 6 with value: 6.615075468116631.
# [I 2024-09-17 12:47:10,870] Trial 8 finished with value: 15.285109378961351 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Mul', 'seasonal': 'Add', 'alpha': 0.760870729625911, 'beta': 0.7656489866199724, 'gamma': 0.6677425924474477}. Best is trial 6 with value: 6.615075468116631.
# [I 2024-09-17 12:47:11,105] Trial 9 finished with value: 22.47233481310047 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': None, 'seasonal': 'Mul', 'alpha': 0.1269409504494542, 'beta': 0.25804902367663507, 'gamma': 0.8087929129039123}. Best is trial 6 with value: 6.615075468116631.
# [I 2024-09-17 12:47:11,187] Trial 10 finished with value: 10.21808717635375 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': None, 'alpha': 0.9836808713259739, 'beta': 0.6156236266077398, 'gamma': 0.4266903270788309}. Best is trial 6 with value: 6.615075468116631.
# [I 2024-09-17 12:47:11,594] Trial 11 finished with value: 5.732674227917209 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.25218614647045795, 'beta': 0.010705549887739974, 'gamma': 0.4996577414769297}. Best is trial 11 with value: 5.732674227917209.
# [I 2024-09-17 12:47:11,995] Trial 12 finished with value: 14.999161375235214 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.2060729681416632, 'beta': 0.022895372265450575, 'gamma': 0.478827115238761}. Best is trial 11 with value: 5.732674227917209.
# [I 2024-09-17 12:47:12,571] Trial 13 finished with value: 24.914943987185598 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.023572124973928077, 'beta': 0.41015752821925955, 'gamma': 0.06907943625329888}. Best is trial 11 with value: 5.732674227917209.
# [I 2024-09-17 12:47:13,116] Trial 14 finished with value: 6.341709567779169 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.2325238394299599, 'beta': 0.6455271083338054, 'gamma': 0.35629668426826283}. Best is trial 11 with value: 5.732674227917209.
# [I 2024-09-17 12:47:13,206] Trial 15 finished with value: 6.747712647207248 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': None, 'alpha': 0.2616884651759393, 'beta': 0.7201349046313154, 'gamma': 0.3402472063471864}. Best is trial 11 with value: 5.732674227917209.
# [I 2024-09-17 12:47:13,590] Trial 16 finished with value: 6.2021262965843995 and parameters: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Add', 'seasonal': 'Mul', 'alpha': 0.38299127863472693, 'beta': 0.3706247664532015, 'gamma': 0.1969107351175225}. Best is trial 11 with value: 5.732674227917209.
# ...
# [I 2024-09-17 14:14:11,664] Trial 132 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:12,652] Trial 133 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:13,643] Trial 134 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:14,606] Trial 135 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:15,538] Trial 136 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:16,491] Trial 137 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:17,440] Trial 138 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:18,429] Trial 139 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:21,493] Trial 140 finished with value: 9.749799792376647 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 2}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:22,480] Trial 141 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:23,440] Trial 142 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:24,409] Trial 143 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:25,431] Trial 144 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:26,635] Trial 145 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:27,528] Trial 146 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:28,452] Trial 147 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:29,432] Trial 148 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:30,527] Trial 149 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:31,716] Trial 150 finished with value: 8.585685863672406 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 1, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:32,767] Trial 151 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:33,799] Trial 152 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:34,875] Trial 153 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:35,849] Trial 154 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:36,903] Trial 155 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:37,883] Trial 156 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:38,907] Trial 157 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:40,105] Trial 158 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:41,038] Trial 159 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:44,350] Trial 160 finished with value: 16.631071716115045 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 2, 'd': 0, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:45,232] Trial 161 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:46,147] Trial 162 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:47,241] Trial 163 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:14:48,235] Trial 164 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:06,169] Trial 165 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:06,817] Trial 166 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:07,407] Trial 167 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:08,293] Trial 168 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:09,267] Trial 169 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:10,307] Trial 170 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:11,412] Trial 171 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:12,641] Trial 172 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:13,698] Trial 173 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:14,752] Trial 174 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:15,688] Trial 175 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:16,737] Trial 176 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:17,781] Trial 177 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:18,792] Trial 178 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:23,087] Trial 179 finished with value: 11.883025181695801 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 3}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:23,936] Trial 180 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:25,152] Trial 181 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:26,597] Trial 182 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:27,686] Trial 183 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:28,472] Trial 184 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:29,100] Trial 185 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:29,771] Trial 186 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:30,414] Trial 187 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:31,018] Trial 188 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:31,625] Trial 189 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:32,240] Trial 190 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:32,904] Trial 191 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:33,526] Trial 192 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:34,135] Trial 193 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:34,804] Trial 194 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:35,523] Trial 195 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:36,179] Trial 196 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:36,797] Trial 197 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:37,986] Trial 198 finished with value: 8.831373994463242 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 3, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# [I 2024-09-17 14:15:38,609] Trial 199 finished with value: 7.591136049525463 and parameters: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}. Best is trial 35 with value: 7.591136049525463.
# ------------------------------------------------------------------
# Producto: producto1
# Tipo: ETS
# RMSE: 5.080119092296547
# Best Params: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Mul', 'seasonal': 'Mul', 'alpha': 0.3614721738156278, 'beta': 0.010663224340918544, 'gamma': 0.28139065996817625}
# --------------------------------------------------
# Producto: producto1
# Tipo: ARIMA
# RMSE: 5.5545702607327385
# Best Params: {'sample_size': 96, 'test_period': 6, 'p': 3, 'd': 3, 'q': 3}
# --------------------------------------------------
# Producto: producto1
# Tipo: Promedio movil
# RMSE: 17.011191792920002
# Best Params: {'sample_size': 96, 'test_period': 6, 'window': 7, 'min_periods': 4}
# --------------------------------------------------
# Producto: producto1
# Tipo: OLS
# RMSE: 17.469130441686975
# Best Params: {'sample_size': 96, 'test_period': 6, 'Estacionalidad': 'Si', 'grado': 7}
# --------------------------------------------------
# Producto: producto2
# Tipo: ETS
# RMSE: 7.189164614410106
# Best Params: {'sample_size': 127, 'test_period': 24, 'error': 'Add', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.971673646631525, 'beta': 0.6846305207518105, 'gamma': 0.6450245265667924}
# --------------------------------------------------
# Producto: producto2
# Tipo: ARIMA
# RMSE: 7.591136049525463
# Best Params: {'sample_size': 127, 'test_period': 24, 'p': 0, 'd': 2, 'q': 0}
# --------------------------------------------------
# Producto: producto2
# Tipo: Promedio movil
# RMSE: 42.67709837496923
# Best Params: {'sample_size': 127, 'test_period': 24, 'window': 7, 'min_periods': 3}
# --------------------------------------------------
# Producto: producto2
# Tipo: OLS
# RMSE: 44.426219893856334
# Best Params: {'sample_size': 127, 'test_period': 24, 'Estacionalidad': 'No', 'grado': 7}
# --------------------------------------------------

# %% [markdown]
# Se listan los hiperparametros y el modelo seleccionado para el mejor RSME,

# %%
df_results = df_results.loc[df_results.groupby('producto')['rmse'].idxmin()]
for index, row in df_results.iterrows():
    print(f"Producto: {row['producto']}")
    print(f"Tipo: {row['tipo']}")
    print(f"RMSE: {row['rmse']}")
    print(f"Best Params: {row['best_params']}")
    print("--------------------------------------------------")
# Out:
# Producto: producto1
# Tipo: ETS
# RMSE: 5.080119092296547
# Best Params: {'sample_size': 96, 'test_period': 6, 'error': 'Add', 'trend': 'Mul', 'seasonal': 'Mul', 'alpha': 0.3614721738156278, 'beta': 0.010663224340918544, 'gamma': 0.28139065996817625}
# --------------------------------------------------
# Producto: producto2
# Tipo: ETS
# RMSE: 7.189164614410106
# Best Params: {'sample_size': 127, 'test_period': 24, 'error': 'Add', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.971673646631525, 'beta': 0.6846305207518105, 'gamma': 0.6450245265667924}
# --------------------------------------------------

# %%
# Se agrega un periodo adicional para el cual se estarán realizando las predicciones
ind = data.index[-1]
value = ind + pd.DateOffset(months=1)
data.loc[value]= 0

# %% [markdown]
# Se realiza la predicción de 1 período, para el modelo seleccionado considerando los hiperparametros ya calculados, para cada producto se determina un modelo e hiperpaametros propios, lo que nos lleva a iterar y mostrar los valores para cada caso.

# %%
for index, row in df_results.iterrows():
    producto     = row['producto']
    tipo         = row['tipo']
    best_params  = row['best_params']
    sample_size  = best_params['sample_size']
        
    model_optimization = ModelOptimization(data[[producto]])
    
    if tipo == 'Promedio movil':
        test_period = 1 # best_params['test_period']
        window      = best_params['window']
        min_periods = best_params['min_periods']
        rmse = model_optimization.promedio_movil(sample_size=sample_size, test_period=test_period, window=window, min_periods=min_periods)
    
    elif tipo == 'ETS':
        test_period = 1 #best_params['test_period']
        error       = best_params['error']
        trend       = best_params['trend']
        seasonal    = best_params['seasonal']
        alpha       = best_params['alpha']
        beta        = best_params['beta']
        gamma       = best_params['gamma']
        rmse = model_optimization.calcular_ets(sample_size=sample_size, test_period=test_period, error=error, trend=trend, seasonal=seasonal, alpha=alpha, beta=beta, gamma=gamma)
    
    elif tipo == 'OLS':
        test_period    = 1 #best_params['test_period']
        estacionalidad = best_params['Estacionalidad']
        grado          = best_params['grado']
        rmse = model_optimization.calcular_ols(sample_size=sample_size, test_period=test_period, estacionalidad=estacionalidad, grado=grado)
    
    elif tipo == 'ARIMA':
        test_period = 1 #best_params['test_period']
        p           = best_params['p']
        d           = best_params['d']
        q           = best_params['q']
        rmse = model_optimization.calcular_arima(sample_size=sample_size, test_period=test_period, p=p, d=d, q=q)
    
    print(f"Con los mejores parámetros para el producto: {producto}:")
    print(f"Modelo: {tipo}")
    print(f"Parámetros: {best_params}")
    for date, value in model_optimization.y_pred.items():
        fecha = date.date()
#       hora = date.time()
        print(f"Predicción para {fecha} de: {value}")
    print("--------------------------------------------------")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for index, row in df_results.iterrows():
#       2     producto     = row['producto']
#       3     tipo         = row['tipo']
#
# NameError: name 'df_results' is not defined

# %% [markdown]
# ### **5.2 Escogencia del mejor modelo**

# %% [markdown]
# #### **5.2.1 Producto 1**

# %% [markdown]
# Los resultados de optimización bayesiana para el parámetro RMSE de los modelos probados son los siguientes:
#
# Optimización para el producto: producto1
# Mejor RMSE para promedio móvil: 8.554295238759712
# Mejor RMSE para ETS: 5.308537484864874
# Mejor RMSE para OLS: 33.51442929548304
# Mejor RMSE para ARIMA: 5.967434579717731
# Mejores parámetros para promedio móvil: {'test_period': 6, 'window': 9, 'min_periods': 2}
# Mejores parámetros para ETS: {'test_period': 6, 'error': 'Mul', 'trend': None, 'seasonal': 'Add', 'alpha': 0.  6159281128631826, 'beta': 0.15108536441364648, 'gamma': 0.48225875023126147}
# Mejores parámetros para OLS: {'test_period': 12, 'Estacionalidad': 'No', 'grado': 6}
# Mejores parámetros para ARIMA: {'test_period': 6, 'p': 3, 'd': 1, 'q': 2}

# %% [markdown]
# Según los resultados anteriores, el mejor modelo es ETS con las siguientes características:
# Mejor RMSE para ETS: 5.308537484864874
# Mejores parámetros para ETS: {'test_period': 6, 'error': 'Mul', 'trend': None, 'seasonal': 'Add', 'alpha': 0.  6159281128631826, 'beta': 0.15108536441364648, 'gamma': 0.48225875023126147}

# %% [markdown]
# #### **5.2.2 Producto 2**

# %% [markdown]
# Los resultados de optimización bayesiana para el parámetro RMSE de los modelos probados son los siguientes:
#
# Optimización para el producto: producto2
# Mejor RMSE para promedio móvil: 221.24582896066335
# Mejor RMSE para ETS: 7.1900793456018945
# Mejor RMSE para OLS: 31.228670865440034
# Mejor RMSE para ARIMA: 8.69716307430175
# Mejores parámetros para promedio móvil: {'test_period': 6, 'window': 7, 'min_periods': 2}
# Mejores parámetros para ETS: {'test_period': 24, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.9892178225728151, 'beta': 0.6864931912226244, 'gamma': 0.8335838425155936}
# Mejores parámetros para OLS: {'test_period': 6, 'Estacionalidad': 'No', 'grado': 2}
# Mejores parámetros para ARIMA: {'test_period': 18, 'p': 2, 'd': 1, 'q': 0}

# %% [markdown]
# Según los resultados anteriores, el mejor modelo es ETS con las siguientes características:
# Mejor RMSE para ETS: 7.1900793456018945
# Mejores parámetros para ETS: {'test_period': 24, 'error': 'Mul', 'trend': 'Mul', 'seasonal': None, 'alpha': 0.9892178225728151, 'beta': 0.6864931912226244, 'gamma': 0.8335838425155936}

# %% [markdown]
# ### **5.3  Validación de supuestos**

# %% [markdown]
# #### **5.3.1 Producto 1**

# %% [markdown]
# Dado que el mejor modelo es ETS, no es necesario validar supuestos

# %% [markdown]
# #### **5.3.2 Producto 2**

# %% [markdown]
# Dado que el mejor modelo es ETS, no es necesario validar supuestos

# %% [markdown]
# ## **6.  Pronosticos**

# %% [markdown]
# ### **6.1  Producto 1 (se ajusta el mejor modelo final completo con los mejores hiperparámetros)**

# %% [markdown]
# ### **6.2  Producto 2**

# %% [markdown]
# ## **7.  Conclusiones**
